# %%
# cora
ori=[1452,1462,1489,1420,1236]
ori_del=[100,100,100,100,100,]
re=[0,0,0,0,0,]
tot=2708
tot_del=100
re_del=[0,0,0,0,0,]
ScaleGUN_del=[0,0,0,0,0,]
ScaleGUN=[0,6,1,2,2]
cgu_del=[0,0,0,0,0,]
cgu=[4,2,2,2,2]
# sgc
# Replay test false: 0 100 Total test false: 4 2708
# Replay test false: 0 100 Total test false: 2 2708
# Replay test false: 0 100 Total test false: 2 2708
# Replay test false: 0 100 Total test false: 2 2708
# Replay test false: 0 100 Total test false: 2 2708

# %%
# arxiv
ori=[1592,1761,1648,1919,1592]
ori_del=[107,118,118,117,107]
re=[0,0,0,0,0,]
tot=169343
tot_del=125
re_del=[0,0,0,0,0,]
ScaleGUN_del=[0,0,0,0,0,]
ScaleGUN=[0,0,0,0,0,]
cgu_del=[0,0,0,0,0,]
cgu=[0,0,0,0,0,]
# sgc
# Replay test false: 0 125 Total test false: 0 169343
# Replay test false: 0 125 Total test false: 0 169343
# Replay test false: 0 125 Total test false: 0 169343
# Replay test false: 0 125 Total test false: 0 169343
# Replay test false: 0 125 Total test false: 0 169343

# %%
# products
ori=[1034720,917300,919278,919451,1791560]
tot=2449029
tot_del=20000
ori_del=[20000,20000,20000,20000, 20000]
re=[0,0,0,0,0,]
re_del=[0,0,0,0,0,]
ScaleGUN_del=[0,0,0,0,0,]
ScaleGUN=[0,0,0,0,0,]
cgu_del=[0,0,0,0,0,]
cgu=[0,0,0,0,0,]

# %%
import numpy as np
re_del=np.array(re_del)
re=np.array(re)
ori=np.array(ori)
ori_del=np.array(ori_del)
ScaleGUN_del=np.array(ScaleGUN_del)
ScaleGUN=np.array(ScaleGUN)
cgu_del=np.array(cgu_del)
cgu=np.array(cgu)

print(f"ori del:{(ori_del/tot_del).mean()} {(ori_del/tot_del).std()}")
print(f"retrain del:{(re_del/tot_del).mean()} {(re_del/tot_del).std()}")
print(f"cgu del:{(cgu_del/tot_del).mean()} {(cgu_del/tot_del).std()}")
print(f"ScaleGUN del:{(ScaleGUN_del/tot_del).mean()} {(ScaleGUN_del/tot_del).std()}")

print(f"ori:{(ori/tot).mean()} {(ori/tot).std()}")
print(f"retrain:{(re/tot).mean()} {(re/tot).std()}")
print(f"cgu:{(cgu/tot).mean()} {(cgu/tot).std()}")
print(f"ScaleGUN:{(ScaleGUN/tot).mean()} {(ScaleGUN/tot).std()}")


print(f"retrain del:{(re_del).mean()} {(re_del).std()}")
print(f"ScaleGUN del:{(ScaleGUN_del).mean()} {(ScaleGUN_del).std()}")
print(f"retrain:{(re).mean()} {(re).std()}")
print(f"ScaleGUN:{(ScaleGUN).mean()} {(ScaleGUN).std()}")
print(f"retrain:{(ori).mean()} {(ori).std()}")
print(f"ScaleGUN:{(ori_del).mean()} {(ori_del).std()}")
